# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
def check_result(row):
    game=(df['home_team']==row['home_team']) & (df['away_team']==row['away_team'])
    proba=list(df[game][['Home','Draw','Away']].values[0])
    max_proba=proba.index(max(proba))
    if max_proba == 0:
        result=list(df[game][['Home','odds_home']].values[0])
        result.append('Home')
    elif max_proba == 1:
        result = list(df[game][['Draw','odds_draw']].values[0])
        result.append('Draw')
    else:
        result = list(df[game][['Away','odds_away']].values[0])
        result.append('Away')
    return result

# %%
df=pd.read_csv('preview.csv')
new_df = df[['league','home_team', 'away_team']]
new_df[['proba','odds','aposta']]=new_df.apply(lambda row: check_result(row), axis=1,result_type="expand")
new_df.reset_index(drop=True,inplace=True)
new_df=new_df.loc[new_df['proba']>=0.55,:].reset_index(drop=True)

# %%
def work_kelly(df,valor):
    kellys=[]
    for proba in df[['odds','proba']].values:
        kellys.append(((proba[0]-1)*proba[1]-(1-proba[1]))/(proba[0]-1))
    df['kellys']=kellys
    df=df.loc[df['kellys']>0,:]
    df['kellys'] = df['kellys']/np.sum(df['kellys'])
    df['aposta']=(df['kellys']*valor).round(2)
    return df

# %%
valor = 100
new_df=work_kelly(new_df,valor)
if new_df['aposta'].min() < 1:
    new_df=new_df.loc[new_df['aposta']>1,:]
    new_df=work_kelly(new_df,valor)

# %%
new_df
# Out:
#                     league                home_team               away_team  \
# 0           Premier League   Brighton & Hove Albion        Newcastle United
# 1           Premier League         Sheffield United                 Everton
# 2           Premier League  Wolverhampton Wanderers          Crystal Palace
# 4           Premier League        Manchester United         West Ham United
# 5           Premier League                Liverpool                 Chelsea
# 6             Championship               Stoke City               Brentford
# 7             Championship             Swansea City            Bristol City
# 9                  La Liga               CA Osasuna            RCD Mallorca
# 10                 Serie A                 Cagliari                Sassuolo
# 11                 Serie A                 AC Milan                 Bologna
# 12                 Serie A                    Parma               Sampdoria
# 13                 Serie A                    Genoa                   Lecce
# 14                 Serie A                  Brescia                    SPAL
# 15                 Serie A               Fiorentina                  Torino
# 16                 Serie A                   Napoli                 Udinese
# 17                 Serie A                     Roma             Inter Milan
# 18                 Serie A                 Juventus                   Lazio
# 19                Liga NOS               Rio Ave FC             Santa Clara
# 20             Eliteserien                Mjøndalen         FK Bodo - Glimt
# 21             Eliteserien                Haugesund                  Viking
# 24             Eliteserien             Sarpsborg 08                     Odd
# 25             Eliteserien                 Aalesund                  Stabæk
# 27             Allsvenskan                   Sirius              Norrköping
# 29             Allsvenskan                 Elfsborg              Djurgården
# 30             Allsvenskan               Falkenberg             Helsingborg
# 31             Allsvenskan            Östersunds FK                  Häcken
# 32             Allsvenskan                 Hammarby            IFK Göteborg
# 33             Allsvenskan                   Örebro                 Mjällby
# 34  Russian Premier League                   Rostov                   Zenit
# 35  Russian Premier League            Dinamo Moskva                Orenburg
# 36  Russian Premier League              Rubin Kazan          Spartak Moskva
# 37             Úrvalsdeild                       KA                  Grótta
# 38             Úrvalsdeild                  Fjölnir                      FH
# 39             Úrvalsdeild                   Fylkir                      KR
# 40             Úrvalsdeild       Víkingur Reykjavík                      ÍA
# 41                Prva HNL               Istra 1961           Dinamo Zagreb
