# %%
import pandas as pd

# %%
df=pd.read_csv('preview.csv')

# %%
new_df = df[[ 'league','home_team', 'away_team']]

# %%
def check_result(row):
    game=(df['home_team']==row['home_team']) & (df['away_team']==row['away_team'])
    proba=list(df[game][['Home','Draw','Away']].values[0])
    max_proba=proba.index(max(proba))
    if max_proba == 0:
        result=list(df[game][['Home','odds_home']].values[0])
        result.append('Home')
    elif max_proba == 1:
        result = list(df[game][['Draw','odds_draw']].values[0])
        result.append('Draw')
    else:
        result = list(df[game][['Away','odds_away']].values[0])
        result.append('Away')
    return result

# %%
new_df[['proba','odds','aposta']]=new_df.apply(lambda row: check_result(row), axis=1,result_type="expand")

# %%
new_df.reset_index(drop=True,inplace=True)

# %%
new_df['odds']=new_df['odds'].apply(lambda x:(x-1))
# Out:
# c:\users\pedro\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
new_df['ev']=new_df['odds']*new_df['proba']
# Out:
# c:\users\pedro\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
new_df.shape
# Out:
# (72, 7)

# %%
new_df.loc[new_df['proba']>=0.55,:]
# Out:
#                     league                home_team               away_team  \
# 3           Premier League   Brighton & Hove Albion        Newcastle United
# 4           Premier League         Sheffield United                 Everton
# 5           Premier League  Wolverhampton Wanderers          Crystal Palace
# 6           Premier League                  Watford         Manchester City
# 8           Premier League        Manchester United         West Ham United
# 9           Premier League                Liverpool                 Chelsea
# 10            Championship               Stoke City               Brentford
# 11            Championship             Swansea City            Bristol City
# 17                 La Liga               Granada CF    Athletic Club Bilbao
# 20                 La Liga               CA Osasuna            RCD Mallorca
# 23                 Serie A                 Cagliari                Sassuolo
# 24                 Serie A                 AC Milan                 Bologna
# 25                 Serie A                    Parma               Sampdoria
# 26                 Serie A                    Genoa                   Lecce
# 27                 Serie A                  Brescia                    SPAL
# 28                 Serie A               Fiorentina                  Torino
# 29                 Serie A                   Napoli                 Udinese
# 30                 Serie A                     Roma             Inter Milan
# 31                 Serie A                 Juventus                   Lazio
# 32                Liga NOS               Rio Ave FC             Santa Clara
# 36             Eliteserien                Mjøndalen         FK Bodo - Glimt
# 37             Eliteserien                Haugesund                  Viking
# 38             Eliteserien                Rosenborg              Sandefjord
# 39             Eliteserien             Kristiansund               Vålerenga
# 41             Eliteserien             Sarpsborg 08                     Odd
# 42             Eliteserien                 Aalesund                  Stabæk
# 43             Eliteserien                    Brann                   Start
# 44             Allsvenskan                   Sirius              Norrköping
# 45             Allsvenskan                 Malmö FF                  Kalmar
# 46             Allsvenskan                 Elfsborg              Djurgården
# 47             Allsvenskan               Falkenberg             Helsingborg
# 48             Allsvenskan            Östersunds FK                  Häcken
# 49             Allsvenskan                 Hammarby            IFK Göteborg
# 50             Allsvenskan                   Örebro                 Mjällby
# 51  Russian Premier League                   Rostov                   Zenit
# 53  Russian Premier League            Dinamo Moskva                Orenburg
# 54  Russian Premier League              Rubin Kazan          Spartak Moskva
# 55             Úrvalsdeild                       KA                  Grótta
# 56             Úrvalsdeild                  Fjölnir                      FH
# 57             Úrvalsdeild                   Fylkir                      KR
# 58             Úrvalsdeild       Víkingur Reykjavík                      ÍA
# 59                Prva HNL               Istra 1961           Dinamo Zagreb
# 61                Prva HNL        Lokomotiva Zagreb                  Gorica
# 62                Prva HNL             Hajduk Split                  Rijeka
# 63                A-League           Perth Glory FC  Central Coast Mariners
# 64                A-League            Brisbane Roar         Adelaide United
# 65                A-League                Sydney FC       Newcastle Jets FC
# 66               J1 League           Vegalta Sendai       Consadole Sapporo
# 67               J1 League          Kashima Antlers     Yokohama F. Marinos
# 68               J1 League                 Yokohama       Kawasaki Frontale
# 69               J1 League           Nagoya Grampus              Sagan Tosu
# 71               J1 League                    Tokyo              Urawa Reds
#
#        proba  odds aposta        ev
# 3   0.893563  0.93   Home  0.831014
# 4   0.900733  1.17   Home  1.053858
# 5   0.899561  0.49   Home  0.440785
# 6   0.824615  0.30   Away  0.247384
# 8   0.919998  0.26   Home  0.239200
# 9   0.906347  1.01   Home  0.915410
# 10  0.819582  4.59   Home  3.761883
# 11  0.793821  0.85   Home  0.674747
# 17  0.580954  1.05   Home  0.610002
# 20  0.553057  3.26   Away  1.802966
# 23  0.614635  2.19   Home  1.346052
# 24  0.858986  0.51   Home  0.438083
# 25  0.786844  2.02   Home  1.589425
# 26  0.854101  0.82   Home  0.700363
# 27  0.735563  1.33   Home  0.978299
# 28  0.869714  0.97   Home  0.843622
# 29  0.806147  0.51   Home  0.411135
# 30  0.593934  2.05   Home  1.217565
# 31  0.788767  0.65   Home  0.512698
# 32  0.813970  0.53   Home  0.431404
# 36  0.597253  5.36   Home  3.201274
# 37  0.649005  1.11   Home  0.720395
# 38  0.589514  0.27   Home  0.159169
# 39  0.597253  1.20   Home  0.716703
# 41  0.664109  1.13   Home  0.750443
# 42  0.649005  1.83   Home  1.187679
# 43  0.589514  0.55   Home  0.324233
# 44  0.762525  2.62   Draw  1.997814
# 45  0.821103  0.34   Home  0.279175
# 46  0.848572  2.04   Home  1.731086
# 47  0.855214  2.12   Draw  1.813054
# 48  0.913602  2.66   Draw  2.430182
# 49  0.780027  2.79   Draw  2.176275
# 50  0.836400  1.84   Home  1.538975
# 51  0.715085  1.86   Away  1.330058
# 53  0.732805  7.49   Away  5.488710
# 54  0.894069  1.55   Away  1.385808
# 55  0.912308  4.41   Away  4.023278
# 56  0.898889  0.58   Away  0.521355
# 57  0.856780  2.69   Draw  2.304738
# 58  0.853645  2.91   Draw  2.484107
# 59  0.955700  0.39   Away  0.372723
# 61  0.941989  0.52   Home  0.489834
# 62  0.942043  1.61   Home  1.516690
# 63  0.966631  0.49   Home  0.473649
# 64  0.984395  1.37   Home  1.348622
# 65  0.867364  0.79   Home  0.685218
# 66  0.710430  1.39   Away  0.987497
# 67  0.742387  1.17   Away  0.868593
# 68  0.865610  3.40   Draw  2.943075
# 69  0.858170  0.77   Home  0.660791
# 71  0.894585  2.30   Draw  2.057546
